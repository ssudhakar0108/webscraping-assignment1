# %% [markdown]
# # Write a python program to scrape cricket rankings from ‘www.icc-cricket.com’. You have to scrape:
# #i) Top 10 ODI teams in women’s cricket along with the records for matches, points and rating.
# #ii) Top 10 women’s ODI players along with the records of their team and rating.
# #iii) Top 10 women’s ODI all-rounder along with the records of their team and rating

# %%
## now we use Pandas read_HTML function to scrape table

# %%
import pandas as pd
d=pd.read_html("https://www.icc-cricket.com/rankings/womens/team-rankings/odi")

# %%
df=d[0]

# %%
df
# Out:
#    Pos           Team  T  Matches  M  Points  P  Rating  R
# 0    1    Australia  AUS          15       2436        162
# 1    2        India  IND          15       1812        121
# 2    3      England  ENG          14       1670        119
# 3    4  South Africa  SA          16       1713        107
# 4    5   New Zealand  NZ          15       1384         92
# 5    6   West Indies  WI          12       1025         85
# 6    7     Pakistan  PAK          12        927         77
# 7    8   Bangladesh  BAN           5        306         61
# 8    9     Sri Lanka  SL          11        519         47
# 9   10      Ireland  IRE           2         25         13

# %% [markdown]
# # ii) Top 10 women’s ODI players along with the records of their team and rating

# %%
d=pd.read_html("https://www.icc-cricket.com/rankings/womens/player-rankings/odi")

# %%
df=d[0]

# %% [markdown]
# # batting

# %%
df
# Out:
#                                                  Pos             Player Team  \
# 0                                                  2    Stafanie Taylor   WI
# 1  3  This player has moved up in the rankings si...       Alyssa Healy  AUS
# 2  4  This player has moved down in the rankings ...    Smriti Mandhana  IND
# 3                                                  5  Amy Satterthwaite   NZ
# 4                                                  6     Tammy Beaumont  ENG
# 5                                                  7       Ellyse Perry  AUS
# 6                                                  8        Lizelle Lee   SA
# 7                                                  9    Laura Wolvaardt   SA
# 8                                                 10        Mithali Raj  IND
#
#    Rating
# 0     746
# 1     741
# 2     732
# 3     723
# 4     716
# 5     691
# 6     690
# 7     689
# 8     687

# %% [markdown]
# # bowling

# %%
df=d[1]
df
# Out:
#                                                  Pos          Player Team  \
# 0                                                  2  Marizanne Kapp   SA
# 1                                                  3    Megan Schutt  AUS
# 2                                                  4  Shabnim Ismail   SA
# 3                                                  5  Jhulan Goswami  IND
# 4  6  This player has moved up in the rankings si...    Poonam Yadav  IND
# 5  7  This player has moved up in the rankings si...   Shikha Pandey  IND
# 6  8  This player has moved down in the rankings ...    Ellyse Perry  AUS
# 7                                                  9  Anya Shrubsole  ENG
# 8                                                 10   Deepti Sharma  IND
#
#    Rating
# 0     738
# 1     735
# 2     717
# 3     691
# 4     679
# 5     675
# 6     666
# 7     645
# 8     639

# %% [markdown]
# # allrounder

# %%
df=d[2]
df
# Out:
#                                                  Pos            Player Team  \
# 0                                                  2   Stafanie Taylor   WI
# 1                                                  3    Marizanne Kapp   SA
# 2                                                  4     Deepti Sharma  IND
# 3                                                  5  Dane van Niekerk   SA
# 4  6  This player has moved up in the rankings si...     Jess Jonassen  AUS
# 5  7  This player has moved down in the rankings ...     Sophie Devine   NZ
# 6                                                  8    Natalie Sciver  ENG
# 7                                                  9     Shikha Pandey  IND
# 8                                                 10   Katherine Brunt  ENG
#
#    Rating
# 0     410
# 1     389
# 2     359
# 3     335
# 4     301
# 5     289
# 6     273
# 7     250
# 8     232

# %%
import csv
#save to CSV
df.to_csv('df.csv')
