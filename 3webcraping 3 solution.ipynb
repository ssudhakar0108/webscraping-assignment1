# %% [markdown]
# # Write a python program to display IMDB’s Top rated 100 Indian movies’ data (i.e. Name, IMDB rating, Yearof release and save it in form of a CSV file.

# %%
import selenium
import pandas as pd
from selenium import webdriver

# %%
driver=webdriver.Chrome(r"/home/sudhakar/Downloads/chromedriver")

# %%
url="https://www.imdb.com/list/ls056092300/"

# %%
driver.get(url)

# %%
Name=[]
IMBD_ratings=[]
Year_of_release=[]

# %%
name_tags=driver.find_elements_by_xpath("//h3[@class='lister-item-header']")

# %%
name_tags
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="35f9f4c8dbb670212ef424492c178d3e", element="2cc8a5bf-efc4-4d15-a79b-63cfce8cf1d3")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="35f9f4c8dbb670212ef424492c178d3e", element="2da7f8cf-63b3-4e22-818c-5c67da49a1e4")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="35f9f4c8dbb670212ef424492c178d3e", element="ac88973c-54ee-46aa-9623-a6c3a8418f67")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="35f9f4c8dbb670212ef424492c178d3e", element="442cd1e4-f9ed-4c5c-9c61-bfd6089a819d")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="35f9f4c8dbb670212ef424492c178d3e", element="5c3851d1-dca6-4bf4-a6ae-5805171e6f7d")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="35f9f4c8dbb670212ef424492c178d3e", element="1fb31030-0c7d-418e-a3e1-f1278ecd2d24")>,
# ...

# %%
for i in name_tags:
    name1=i.text
    Name.append(name1)

# %%
Name
# Out:
# ['1. Ship of Theseus (2012)',
#  '2. Iruvar (1997)',
#  '3. Kaagaz Ke Phool (1959)',
#  '4. Lagaan: Once Upon a Time in India (2001)',
#  '5. Pather Panchali (1955)',
#  '6. The Lonely Wife (1964)',
#  '7. Rang De Basanti (2006)',
#  '8. Dev.D (2009)',
#  '9. 3 Idiots (2009)',
#  '10. Awaara (1951)',
#  '11. Nayakan (1987)',
#  '12. Aparajito (1956)',
#  '13. Pushpaka Vimana (1987)',
#  '14. Pyaasa (1957)',
#  '15. The Ritual (1977)',
#  '16. Sholay (1975)',
#  '17. Aradhana (1969)',
#  '18. Do Ankhen Barah Haath (1957)',
#  '19. Bombay (1995)',
#  '20. Neecha Nagar (1946)',
#  '21. Do Bigha Zamin (1953)',
#  '22. Garm Hava (1974)',
#  '23. Piravi (1989)',
#  '24. Mughal-E-Azam (1960)',
#  '25. Amma Ariyan (1987)',
#  '26. Madhumati (1958)',
#  '27. The Adventures of Goopy and Bagha (1969)',
#  '28. Gangs of Wasseypur (2012)',
#  '29. Guide (1965)',
#  '30. Satya (1998)',
#  '31. Roja (1992)',
#  '32. Mr. India (1987)',
#  '33. The Cloud-Capped Star (1960)',
# ...

# %%
imbd_rating_tags=driver.find_elements_by_xpath("//div[@class='ipl-rating-star small']/span[2]")

# %%
imbd_rating_tags
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="35f9f4c8dbb670212ef424492c178d3e", element="cf2e32f1-31db-4b6e-866b-85bc18bb9f02")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="35f9f4c8dbb670212ef424492c178d3e", element="af216650-13c7-4598-96f4-69d9fb896650")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="35f9f4c8dbb670212ef424492c178d3e", element="0e5095a8-749a-46c2-a87e-fee9a444c77b")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="35f9f4c8dbb670212ef424492c178d3e", element="60ea1c17-3b3e-47d3-9a86-a7b1677a87ee")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="35f9f4c8dbb670212ef424492c178d3e", element="f758d2e9-ae65-4d04-ab89-839859d6ab25")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="35f9f4c8dbb670212ef424492c178d3e", element="257512bc-b322-4dcd-99dd-13389849b406")>,
# ...

# %%
for i in imbd_rating_tags:
    rating=i.text
    IMBD_ratings.append(rating)

# %%
IMBD_ratings
# Out:
# ['8',
#  '8.5',
#  '8',
#  '8.1',
#  '8.6',
#  '8.2',
#  '8.2',
#  '8',
#  '8.4',
#  '7.9',
#  '8.6',
#  '8.4',
#  '8.7',
#  '8.5',
#  '7.3',
#  '8.2',
#  '7.6',
#  '8.4',
#  '8.1',
#  '6.8',
#  '8.4',
#  '8.1',
#  '7.7',
#  '8.2',
#  '7.1',
#  '8',
#  '8.8',
#  '8.2',
#  '8.4',
#  '8.2',
#  '8.2',
#  '7.8',
#  '8',
#  '8.4',
#  '8.4',
#  '7.7',
#  '8',
#  '7.9',
#  '8.1',
#  '8.2',
#  '8.3',
#  '8.1',
#  '8.4',
#  '8.2',
#  '7.5',
#  '7.1',
#  '8.4',
#  '8.3',
#  '7.4',
#  '7.8',
#  '8',
#  '8.4',
#  '7.5',
#  '8.2',
#  '7.6',
#  '7.9',
#  '8.5',
#  '7.7',
#  '7.5',
#  '7.8',
#  '8',
#  '7.3',
#  '8.1',
#  '7.4',
#  '8.3',
#  '7.7',
#  '7.6',
#  '7.6',
#  '8.1',
#  '7.9',
#  '6.8',
#  '6.7',
#  '7.7',
#  '8.8',
#  '8.1',
#  '8.2',
#  '7.3',
#  '7.2',
#  '8.3',
#  '7.8',
#  '8.3',
#  '7.7',
#  '8.2',
#  '7.5',
#  '7.6',
#  '7.5',
#  '7.9',
#  '7.2',
#  '8',
#  '7.4',
#  '7.6',
#  '8.4',
#  '7.7',
#  '7.8',
#  '8.4',
#  '8.5',
#  '8.1',
#  '7.3',
#  '8.2',
#  '8.1']

# %%
year_of_release_tags=driver.find_elements_by_xpath("//span[@class='lister-item-year text-muted unbold']")

# %%
year_of_release_tags
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="35f9f4c8dbb670212ef424492c178d3e", element="5bc2def3-3c49-4ecf-8884-d2295e986519")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="35f9f4c8dbb670212ef424492c178d3e", element="fdadbd9e-ba1f-4e21-9687-5f0c094ba3b2")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="35f9f4c8dbb670212ef424492c178d3e", element="7a7f6c1f-ad03-4b13-a5f1-de8e82d95567")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="35f9f4c8dbb670212ef424492c178d3e", element="a8a5fe73-f136-48ad-bc8f-85dfd5c732ef")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="35f9f4c8dbb670212ef424492c178d3e", element="1fd7be7d-4237-4a26-abeb-b39655819315")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="35f9f4c8dbb670212ef424492c178d3e", element="688322e8-8f3f-45ed-8470-f55a4cee6369")>,
# ...

# %%
for i in year_of_release_tags:
    release1=i.text
    Year_of_release.append(release1)

# %%
Year_of_release
# Out:
# ['(2012)',
#  '(1997)',
#  '(1959)',
#  '(2001)',
#  '(1955)',
#  '(1964)',
#  '(2006)',
#  '(2009)',
#  '(2009)',
#  '(1951)',
#  '(1987)',
#  '(1956)',
#  '(1987)',
#  '(1957)',
#  '(1977)',
#  '(1975)',
#  '(1969)',
#  '(1957)',
#  '(1995)',
#  '(1946)',
#  '(1953)',
#  '(1974)',
#  '(1989)',
#  '(1960)',
#  '(1987)',
#  '(1958)',
#  '(1969)',
#  '(2012)',
#  '(1965)',
#  '(1998)',
#  '(1992)',
#  '(1987)',
#  '(1960)',
#  '(2009)',
#  '(1983)',
#  '(1990)',
#  '(1986)',
#  '(1998)',
#  '(2001)',
#  '(2013)',
#  '(1975)',
#  '(1995)',
#  '(2007)',
#  '(1983)',
#  '(1977)',
#  '(2010)',
#  '(1983)',
#  '(2004)',
#  '(1991)',
#  '(1964)',
#  '(1955)',
#  '(2002)',
#  '(1994)',
#  '(2012)',
#  '(1994)',
#  '(2004)',
#  '(2004)',
#  '(1976)',
#  '(1975)',
#  '(2012)',
#  '(1967)',
#  '(1972)',
#  '(2003)',
#  '(1960)',
#  '(1962)',
#  '(1977)',
#  '(1963)',
#  '(2001)',
#  '(2008)',
#  '(2002)',
#  '(1989)',
#  '(1994)',
#  '(2013)',
#  '(1983)',
#  '(2003)',
#  '(1984)',
# ...

# %%
print(len(Name),len(IMBD_ratings),len(Year_of_release))
# Out:
# 100 100 100

# %%
import pandas as pd
movie=pd.DataFrame({})
movie['Name']=Name
movie['IMBD_ratings']=IMBD_ratings
movie['Year_of_release']=Year_of_release

# %%
movie
# Out:
#                                            Name IMBD_ratings Year_of_release
# 0                     1. Ship of Theseus (2012)            8          (2012)
# 1                              2. Iruvar (1997)          8.5          (1997)
# 2                     3. Kaagaz Ke Phool (1959)            8          (1959)
# 3   4. Lagaan: Once Upon a Time in India (2001)          8.1          (2001)
# 4                     5. Pather Panchali (1955)          8.6          (1955)
# ..                                          ...          ...             ...
# 95                  96. The World of Apu (1959)          8.5          (1959)
# 96                       97. Kanchivaram (2008)          8.1          (2008)
# 97                   98. Monsoon Wedding (2001)          7.3          (2001)
# 98                             99. Black (2005)          8.2          (2005)
# 99                          100. Deewaar (1975)          8.1          (1975)
#
# [100 rows x 3 columns]

# %%
import csv
#save to CSV
movie.to_csv('movie.csv')
